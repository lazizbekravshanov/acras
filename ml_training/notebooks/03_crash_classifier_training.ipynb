# %% [markdown]
# # 03 - Crash Classifier Training
#
# Train the binary crash/normal classifier using ResNet18 backbone.

# %%
import sys
sys.path.insert(0, '../../backend')

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# %%
# Build model
from app.ml.crash_classifier import CrashClassifierModel

model = CrashClassifierModel().to(device)
print(f'Model parameters: {sum(p.numel() for p in model.parameters()):,}')
print(f'Trainable: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}')

# %%
# Training loop (see scripts/train_classifier.py for full implementation)
print('Run: python scripts/train_classifier.py --epochs 50')
print('Or use the training script with custom parameters.')
